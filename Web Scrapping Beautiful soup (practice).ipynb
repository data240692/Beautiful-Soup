# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://www.imdb.com/search/title/?sort=user_rating,desc&groups=top_100')

# %%
page
# Out:
# <Response [403]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <html>
# <head><title>403 Forbidden</title></head>
# <body>
# <center><h1>403 Forbidden</h1></center>
# </body>
# </html>

# %% [markdown]
# The above website showing like response more than 400 so i am doing scrapping from some other website

# %%
page = requests.get('https://www.edustoke.com/best-cbse-schools-in-chennai')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>24 Best CBSE Schools in Chennai for Admissions 2024-2025 Session | Edustoke</title>
# <meta charset="utf-8"/>
# <meta content="Find the list of Top and Best CBSE Schools in Chennai 2024-2025 session with admission details, fees, rankings reviews, contact numbers, infrastructure, school facilities and address." name="description"/>
# <meta content="Best CBSE Schools in Chennai, Top 10 Best CBSE Schools in Chennai, List of Top Rated and Best CBSE Schools in Chennai, Best CBSE Schools in Chennai with hostel, Affordable Best CBSE Schools in Chennai, No. 1 Best CBSE Schools in Chennai, Find Fee details, Board, Reviews, Admission Information, Academic details, Sports facility, Infrastructure, safety and security details, Curriculum, Address, Contact details, for all Best CBSE Schools in Chennai - Edustoke" name="keywords"/>
# <link href="https://www.edustoke.com/best-cbse-schools-in-chennai" rel="canonical"/>
# ...

# %%
first_title = soup.find('div', class_= "col col-xl-9" )
first_title
# Out:
# <div class="col col-xl-9">
# <a class="school-name text-capitalize text-truncate d-block notranslate" data-placement="top" data-toggle="tooltip" href="https://www.edustoke.com/chennai/sboa-school-and-junior-college-anna-nagar-west-extension" target="_blank" title="SBOA School And Junior College">SBOA School and Junior College</a>
# </div>

# %%
first_title.text
# Out:
# '\nSBOA School and Junior College\n'

# %%
location = soup.find('div',class_="address-container d-block d-lg-none notranslate")

# %%
location
# Out:
# <div class="address-container d-block d-lg-none notranslate">
# <a class="address d-block text-truncate" href="https://www.google.com/maps/place/13.09287+80.195308/@13.09287,80.195308,18z" target="_blank"><i aria-hidden="true" class="fa fa-map-marker mr-1 text-red"></i> 18, School Road, Anna Nagar West Extension, Chennai, Tamil Nadu</a>
# </div>

# %%
location.text
# Out:
# '\n 18, School Road, Anna Nagar West Extension, Chennai, Tamil Nadu\n'

# %%
fees = soup.find('div', class_="d-flex justify-content-between price-action-wrapper")
fees
# Out:
# <div class="d-flex justify-content-between price-action-wrapper">
# <div class="price-wrapper d-flex">
# <div class="d-flex flex-column justify-content-center mr-3">
# <span class="heading-text">
# Annual Fees
# </span>
# <span class="price font-weight-bold">
# ₹56,790 </span>
# </div>
# </div>
# <div class="school-controls d-flex align-items-center">
# <a class="view" href="https://www.edustoke.com/chennai/sboa-school-and-junior-college-anna-nagar-west-extension" target="_blank">View School</a>
# </div>
# </div>

# %%
fees.text.replace('$','')
# Out:
# '\n\n\n\nAnnual Fees\n\n\n₹56,790 \n\n\n\nView School\n\n'

# %%
titles =[]

# %%
for i in soup.find_all('div', class_="col col-xl-9"):
    titles.append(i.text)
    
titles
# Out:
# ['\nSBOA School and Junior College\n',
#  '\nPadma Seshadri Bala Bhavan Senior Secondary School\n',
#  '\nMaharishi Vidya Mandir\n',
#  '\nPon Vidyashram School\n',
#  '\nMaharishi School Of Excellence\n',
#  '\nD.A.V. Girls Senior Secondary School\n',
#  '\nChettinad Vidyashram\n',
#  '\nD.A.V. Boys Senior Secondary School\n',
#  '\nVels Vidyashram\n',
#  '\nVidya Mandir Senior Secondary School\n',
#  '\nSpartan International School\n',
#  '\nRMK School\n',
#  '\nD.A.V Boys Senior Secondary School\n',
#  '\nLADY ANDAL VENKATASUBBA RAO MATRICULATION SCHOOL\n',
#  '\nD.A.V Girls Senior Secondary School\n',
#  '\nALPHA SCHOOL\n',
#  '\nPon Vidyashram School\n',
#  '\nThe Hindu Senior Secondary School\n',
#  '\nP.S.Senior secondary School\n',
#  '\nArmy public school\n',
#  '\nChennai Public School\n',
#  '\nVelammal Vidhyashram\n',
#  '\nChinmaya Vidyalaya\n',
#  '\nscad world school chengalpattu\n',
#  '\nSBOA School and Junior College\n',
# ...

# %%
for i in soup.find_all('div',class_="address-container d-block d-lg-none notranslate"):
    location.append(i.text)

# %%
location
# Out:
# <div class="address-container d-block d-lg-none notranslate">
# <a class="address d-block text-truncate" href="https://www.google.com/maps/place/13.09287+80.195308/@13.09287,80.195308,18z" target="_blank"><i aria-hidden="true" class="fa fa-map-marker mr-1 text-red"></i> 18, School Road, Anna Nagar West Extension, Chennai, Tamil Nadu</a>
#
#  18, School Road, Anna Nagar West Extension, Chennai, Tamil Nadu
#
#  No.15, Lake 1st Main Road, Nungambakkam, Chennai, Tamil Nadu
#
#  28, Dr. Guruswamy Road, Chetpet, Chennai, Tamil Nadu
#
#  Porur Maxworth Nagar, Phase-II, Mugalivakkam, Kolapakkam, Chennai, Tamil Nadu
#
#  P.T.C. Colony, Pallavan Nagar , Thiruverkadu, Chennai, Tamil Nadu
#
#  Plot No: R-40B, 120 Feet Road, Mogappair, Chennai, Tamil Nadu
#
#  Rajah Annamalaipuram, Chennai, Tamil Nadu
#
#  R-45, 120 feet road, Mogappair, Chennai, Tamil Nadu
#
#  P.V.Vaithiyalingam Road, Velan Nagar, Pallavaram, Rajiv Gandhi Nagar, Tirusulam, Chennai, Tamil Nadu
#
# ...

# %%
page = requests.get('https://www.dineout.co.in/chennai-restaurants/pure-veg')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><link href="/manifest.json" rel="manifest"/><style type="text/css">
#             @font-face {
#                 font-family: 'dineicon';
#                 src:  url('/fonts/dineicon.eot');
#                 src:  url('/fonts/dineicon.eot#iefix') format('embedded-opentype'),
#                 url('/fonts/dineicon.ttf') format('truetype'),
#                 url('/fonts/dineicon.woff') format('woff'),
#                 url('/fonts/dineicon.svg#dineicon') format('svg');
#                 font-weight: normal;
# 				font-style: normal;
# 				font-display: swap;
#             }
#             .hide {
#                 display: none !important;
#             }
#             .async-hide{
#                 opacity: inherit !important;
#             }
# ...

# %%
first_name = soup.find('div',class_="restnt-info cursor")

# %%
first_name
# Out:
# <div class="restnt-info cursor" data-gatype="RestaurantNameClick"><a analytics-action="RestaurantCardClick" analytics-label="48759_Jalpaan" class="restnt-name ellipsis" data-w-onclick="sendAnalyticsCommon|w1-restarant" href="/chennai/jalpaan-saligramam-west-chennai-48759">Jalpaan</a><div class="restnt-loc ellipsis" data-w-onclick="stopClickPropagation|w1-restarant"><a data-name="Saligramam" data-type="LocalityClick" href="/chennai-restaurants/west-chennai/saligramam">Saligramam</a>, <a data-name="West Chennai" data-type="AreaClick" href="/chennai-restaurants/west-chennai">West Chennai</a></div></div>

# %%
first_name.text
# Out:
# 'JalpaanSaligramam, West Chennai'

# %%
loc = soup.find('div',class_="restnt-loc ellipsis")

# %%
loc
# Out:
# <div class="restnt-loc ellipsis" data-w-onclick="stopClickPropagation|w1-restarant"><a data-name="Saligramam" data-type="LocalityClick" href="/chennai-restaurants/west-chennai/saligramam">Saligramam</a>, <a data-name="West Chennai" data-type="AreaClick" href="/chennai-restaurants/west-chennai">West Chennai</a></div>

# %%
loc.text
# Out:
# 'Saligramam, West Chennai'

# %%
price = soup.find('div',class_="detail-info")

# %%
price
# Out:
# <div class="detail-info"><ul><li><span class="double-line-ellipsis"><span>₹ 1,200 for 2 (approx)</span><span> | </span><a data-w-onclick="stopClickPropagation|w1-restarant" href="/chennai-restaurants/italian-cuisine">Italian</a><span>, </span><a data-w-onclick="stopClickPropagation|w1-restarant" href="/chennai-restaurants/chinese-cuisine">Chinese</a><span>, </span><a data-w-onclick="stopClickPropagation|w1-restarant" href="/chennai-restaurants/north-indian-cuisine">North Indian</a></span></li><li class="ellipsis"></li></ul></div>

# %%
price.text.replace('$',' ')
# Out:
# '₹ 1,200 for 2 (approx) | Italian, Chinese, North Indian'

# %%
titles = []

# %%
for i in soup.find_all('div',class_="restnt-info cursor"):
    titles.append(i.text)

# %%
titles
# Out:
# ['JalpaanSaligramam, West Chennai',
#  'Madras Coffee HouseThyagaraya Nagar, Central Chennai',
#  'IdliesThyagaraya Nagar, Central Chennai',
#  'Murugan Idli ShopThyagaraya Nagar, Central Chennai',
#  'Murugan Idli ShopWest Mambalam, West Chennai',
#  'Pakwan ChennaiThyagaraya Nagar, Central Chennai',
#  'Murugan Idli ShopThyagaraya Nagar, Central Chennai',
#  'Murugan Idli ShopThyagaraya Nagar, Central Chennai',
#  'Curly CravingsKodambakkam, West Chennai',
#  'Juice ForestAshok Nagar, West Chennai',
#  'Makers Of MilkshakesKodambakkam, West Chennai',
#  'Paati VeeduThyagaraya Nagar, Central Chennai',
#  'Royal IndianaaThe Accord Metropolitan Hotel,Thyagaraya Nagar, Central Chennai',
#  'The Belgian Waffle CoForum Vijaya Mall,Vadapalani, West Chennai',
#  'Amdavadi Gujarati RestaurantThyagaraya Nagar, Central Chennai',
#  'Murugan Idli ShopVadapalani, West Chennai',
#  'Masaledaar DhabaSaligramam, West Chennai',
#  'Hotel Saravana BhavanSaligramam, West Chennai',
# ...

# %%
price = []

for i in soup.find_all('div',class_="detail-info"):
    price.append(i.text)
    
price
# Out:
# ['₹ 1,200 for 2 (approx) | Italian, Chinese, North Indian',
#  '₹ 200 for 2 (approx) | Beverages, Fast Food',
#  '₹ 300 for 2 (approx) | South Indian',
#  '₹ 300 for 2 (approx) | South Indian',
#  '₹ 300 for 2 (approx) | South Indian',
#  '₹ 800 for 2 (approx) | North Indian, Chinese, Continental, Beverages, Desserts',
#  '₹ 300 for 2 (approx) | South Indian',
#  '₹ 300 for 2 (approx) | South Indian',
#  '₹ 500 for 2 (approx) | Fast Food, Beverages',
#  '₹ 300 for 2 (approx) | Beverages, Desserts',
#  '₹ 400 for 2 (approx) | Beverages, Desserts',
#  '₹ 1,500 for 2 (approx) | South Indian',
#  '₹ 3,200 for 2 (approx) | North Indian, South Indian, Desserts',
#  '₹ 400 for 2 (approx) | Desserts',
#  '₹ 600 for 2 (approx) | Gujarati',
#  '₹ 300 for 2 (approx) | South Indian',
#  '₹ 600 for 2 (approx) | North Indian',
#  '₹ 600 for 2 (approx) | South Indian, North Indian, Chinese, Desserts',
#  '₹ 1,800 for 2 (approx) | North Indian',
#  '₹ 300 for 2 (approx) | Tea',
# ...
